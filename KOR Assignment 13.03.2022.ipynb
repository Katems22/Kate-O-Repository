# %%
import pandas as pd

# %%
data=pd.read_csv("F1 Drivers.csv")

# %%
print(data)
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  07/01/1985
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  10/05/1977
# 2           3          rosberg      6  ROS      Nico     Rosberg  27/06/1985
# 3           4           alonso     14  ALO  Fernando      Alonso  29/07/1981
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  19/10/1981
# ..        ...              ...    ...  ...       ...         ...         ...
# 849       851           aitken     89  AIT      Jack      Aitken  23/09/1995
# 850       852          tsunoda     22  TSU      Yuki     Tsunoda  11/05/2000
# 851       853          mazepin      9  MAZ    Nikita     Mazepin  02/03/1999
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  22/03/1999
# 853       855             zhou     \N  ZHO    Guanyu        Zhou  30/05/1999
#
# ...

# %%
print(data.sort_values("nationality"))
# Out:
#      driverId  driverRef number code  forename    surname         dob  \
# 595       595    garrett     \N   \N     Billy    Garrett  24/04/1933
# 597       597     connor     \N   \N       Pat   O'Connor  09/10/1928
# 596       596    elisian     \N   \N        Ed    Elisian  09/12/1926
# 448       449       ward     \N   \N    Rodger       Ward  10/01/1921
# 594       594      tolan     \N   \N   Johnnie      Tolan  22/10/1917
# ..        ...        ...    ...  ...       ...        ...         ...
# 568       568     fontes     \N   \N  Azdrubal     Fontes  26/12/1922
# 748       748    cantoni     \N   \N     Eitel    Cantoni  04/10/1906
# 812       813  maldonado     13  MAL    Pastor  Maldonado  09/03/1985
# 187       188    cecotto     \N   \N    Johnny    Cecotto  25/01/1956
# 503       503    chimeri     \N   \N    Ettore    Chimeri  04/06/1921
#
#     nationality                                                url
# ...

# %%
print(data)
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  07/01/1985
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  10/05/1977
# 2           3          rosberg      6  ROS      Nico     Rosberg  27/06/1985
# 3           4           alonso     14  ALO  Fernando      Alonso  29/07/1981
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  19/10/1981
# ..        ...              ...    ...  ...       ...         ...         ...
# 849       851           aitken     89  AIT      Jack      Aitken  23/09/1995
# 850       852          tsunoda     22  TSU      Yuki     Tsunoda  11/05/2000
# 851       853          mazepin      9  MAZ    Nikita     Mazepin  02/03/1999
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  22/03/1999
# 853       855             zhou     \N  ZHO    Guanyu        Zhou  30/05/1999
#
# ...

# %%
print(data.groupby("nationality"))

# %%
data.groupby(["forename","surname"])["nationality"].sum()
# Out:
# forename  surname
# Adolf     Brudes            German
# Adolfo    Cruz           Argentine
# Adrian    Sutil             German
# Adrián    Campos           Spanish
# Aguri     Suzuki          Japanese
#                            ...
# Zsolt     Baumgartner    Hungarian
# Élie      Bayol             French
# Éric      Bernard           French
# Érik      Comas             French
# Óscar     González       Uruguayan
# Name: nationality, Length: 854, dtype: object

# %%
standings=pd.read_csv("driver_standings.csv")

# %%
print(standings)
# Out:
#        driverStandingsId  raceId  driverId  points  position positionText  \
# 0                      1      18         1    10.0         1            1
# 1                      2      18         2     8.0         2            2
# 2                      3      18         3     6.0         3            3
# 3                      4      18         4     5.0         4            4
# 4                      5      18         5     4.0         5            5
# ...                  ...     ...       ...     ...       ...          ...
# 33389              70776    1074       840     0.0        16            -
# 33390              70777    1074       852     0.0        17            -
# 33391              70778    1074       830     0.0        18            -
# 33392              70779    1074        20     0.0        19            -
# 33393              70780    1074       855     0.0        20            -
#
#        wins
# 0         1
# 1         0
# 2         0
# 3         0
# ...

# %%
print(standings.groupby("wins").mean())
# Out:
#       driverStandingsId      raceId    driverId      points   position
# wins
# 0          41245.933087  566.636969  311.883496    6.127703  22.332971
# 1          40263.467391  543.906126  245.276680   34.851196   4.398221
# 2          40437.842233  528.865291  202.904126   62.874393   2.741505
# 3          38018.086849  512.215881  145.431762   79.676526   2.064516
# 4          35500.177686  477.442149  114.301653   92.948926   1.516529
# 5          40124.505952  542.970238  125.107143  111.794643   1.529762
# 6          31641.715447  406.764228   94.040650  105.589431   1.235772
# 7          32670.650000  467.916667  105.166667  138.416667   1.216667
# 8          43321.771429  605.114286   54.285714  191.671429   1.085714
# 9          51603.371429  762.857143  111.514286  268.714286   1.028571
# 10         56340.631579  792.105263   52.736842  306.184211   1.052632
# 11         58459.833333  817.250000   12.166667  329.750000   1.000000
# ...

# %%
data_with_standings=data.merge(standings, on = "driverId",suffixes = ("_data","_st"), how="left")

# %%
print(data_with_standings)
# Out:
#        driverId        driverRef number code forename     surname         dob  \
# 0             1         hamilton     44  HAM    Lewis    Hamilton  07/01/1985
# 1             1         hamilton     44  HAM    Lewis    Hamilton  07/01/1985
# 2             1         hamilton     44  HAM    Lewis    Hamilton  07/01/1985
# 3             1         hamilton     44  HAM    Lewis    Hamilton  07/01/1985
# 4             1         hamilton     44  HAM    Lewis    Hamilton  07/01/1985
# ...         ...              ...    ...  ...      ...         ...         ...
# 33396       854  mick_schumacher     47  MSC     Mick  Schumacher  22/03/1999
# 33397       854  mick_schumacher     47  MSC     Mick  Schumacher  22/03/1999
# 33398       854  mick_schumacher     47  MSC     Mick  Schumacher  22/03/1999
# 33399       854  mick_schumacher     47  MSC     Mick  Schumacher  22/03/1999
# 33400       855             zhou     \N  ZHO   Guanyu        Zhou  30/05/1999
#
# ...

# %%
youngest = data_with_standings["dob"].max()

# %%
print(youngest)
# Out:
# 31/10/1988

# %%
pd.read_csv("constructors.csv")
# Out:
#      constructorId constructorRef            name nationality  \
# 0                1        mclaren         McLaren     British
# 1                2     bmw_sauber      BMW Sauber      German
# 2                3       williams        Williams     British
# 3                4        renault         Renault      French
# 4                5     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 206            209          manor  Manor Marussia     British
# 207            210           haas    Haas F1 Team    American
# 208            211   racing_point    Racing Point     British
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren
# 1              http://en.wikipedia.org/wiki/BMW_Sauber
# ...

# %%
pd.read_csv("constructor_standings.csv")
# Out:
#        constructorStandingsId  raceId  constructorId  points  position  \
# 0                           1      18              1    14.0         1
# 1                           2      18              2     8.0         3
# 2                           3      18              3     9.0         2
# 3                           4      18              4     5.0         4
# 4                           5      18              5     2.0         5
# ...                       ...     ...            ...     ...       ...
# 12711                   27938    1074            210     0.0         6
# 12712                   27939    1074              1     0.0         7
# 12713                   27940    1074            131     0.0         8
# 12714                   27941    1074              9     0.0         9
# 12715                   27942    1074              3     0.0        10
#
#       positionText  wins
# 0                1     1
# 1                3     0
# 2                2     0
# ...

# %%
pd.read_csv("races.csv")
# Out:
#       raceId  year  round  circuitId                      name        date  \
# 0          1  2009      1          1     Australian Grand Prix  2009-03-29
# 1          2  2009      2          2      Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17        Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3        Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4        Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                       ...         ...
# 1075    1092  2022     19         22       Japanese Grand Prix  2022-10-09
# 1076    1093  2022     20         69  United States Grand Prix  2022-10-23
# 1077    1094  2022     21         32    Mexico City Grand Prix  2022-10-30
# 1078    1095  2022     22         18      São Paulo Grand Prix  2022-11-13
# 1079    1096  2022     23         24      Abu Dhabi Grand Prix  2022-11-20
#
#           time                                                url
# ...

# %%
F1_Races=(pd.read_csv("races.csv"))

# %%
print(F1_Races)
# Out:
#       raceId  year  round  circuitId                      name        date  \
# 0          1  2009      1          1     Australian Grand Prix  2009-03-29
# 1          2  2009      2          2      Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17        Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3        Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4        Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                       ...         ...
# 1075    1092  2022     19         22       Japanese Grand Prix  2022-10-09
# 1076    1093  2022     20         69  United States Grand Prix  2022-10-23
# 1077    1094  2022     21         32    Mexico City Grand Prix  2022-10-30
# 1078    1095  2022     22         18      São Paulo Grand Prix  2022-11-13
# 1079    1096  2022     23         24      Abu Dhabi Grand Prix  2022-11-20
#
#           time                                                url
# ...

# %%
F1_Races.sort_values("year")
# Out:
#       raceId  year  round  circuitId                      name        date  \
# 838      839  1950      7         14        Italian Grand Prix  1950-09-03
# 837      838  1950      6         55         French Grand Prix  1950-07-02
# 836      837  1950      5         13        Belgian Grand Prix  1950-06-18
# 835      836  1950      4         66          Swiss Grand Prix  1950-06-04
# 834      835  1950      3         19          Indianapolis 500  1950-05-30
# ...      ...   ...    ...        ...                       ...         ...
# 1058    1075  2022      2         77  Saudi Arabian Grand Prix  2022-03-27
# 1078    1095  2022     22         18      São Paulo Grand Prix  2022-11-13
# 1036    1074  2022      1          3        Bahrain Grand Prix  2022-03-20
# 1067    1084  2022     11         70       Austrian Grand Prix  2022-07-12
# 1079    1096  2022     23         24      Abu Dhabi Grand Prix  2022-11-20
#
#           time                                                url
# ...

# %%
oldest_race=F1_Races["year"].min()

# %%
print(oldest_race)
# Out:
# 1950

# %%
recent_race=F1_Races["year"].max()

# %%
print(recent_race)
# Out:
# 2022

# %%
Const_standings=(pd.read_csv("constructor_standings.csv"))

# %%
print(Const_standings)
# Out:
#        constructorStandingsId  raceId  constructorId  points  position  \
# 0                           1      18              1    14.0         1
# 1                           2      18              2     8.0         3
# 2                           3      18              3     9.0         2
# 3                           4      18              4     5.0         4
# 4                           5      18              5     2.0         5
# ...                       ...     ...            ...     ...       ...
# 12711                   27938    1074            210     0.0         6
# 12712                   27939    1074              1     0.0         7
# 12713                   27940    1074            131     0.0         8
# 12714                   27941    1074              9     0.0         9
# 12715                   27942    1074              3     0.0        10
#
#       positionText  wins
# 0                1     1
# 1                3     0
# 2                2     0
# ...

# %%
Const_standings.groupby("constructorId")["points"].agg([sum])
# Out:
#                    sum
# constructorId
# 1              55236.5
# 2               2932.0
# 3              32004.5
# 4              17168.0
# 5               5193.0
# ...                ...
# 209               13.0
# 210             2597.0
# 211             2349.0
# 213             2315.0
# 214             1517.0
#
# [159 rows x 1 columns]

# %%
constructors=(pd.read_csv("constructors.csv"))

# %%
print(constructors)
# Out:
#      constructorId constructorRef            name nationality  \
# 0                1        mclaren         McLaren     British
# 1                2     bmw_sauber      BMW Sauber      German
# 2                3       williams        Williams     British
# 3                4        renault         Renault      French
# 4                5     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 206            209          manor  Manor Marussia     British
# 207            210           haas    Haas F1 Team    American
# 208            211   racing_point    Racing Point     British
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren
# 1              http://en.wikipedia.org/wiki/BMW_Sauber
# ...

# %%
Const_standings.isna()
# Out:
#        constructorStandingsId  raceId  constructorId  points  position  \
# 0                       False   False          False   False     False
# 1                       False   False          False   False     False
# 2                       False   False          False   False     False
# 3                       False   False          False   False     False
# 4                       False   False          False   False     False
# ...                       ...     ...            ...     ...       ...
# 12711                   False   False          False   False     False
# 12712                   False   False          False   False     False
# 12713                   False   False          False   False     False
# 12714                   False   False          False   False     False
# 12715                   False   False          False   False     False
#
#        positionText   wins
# 0             False  False
# 1             False  False
# 2             False  False
# ...

# %%
drivers=pd.read_csv("F1 Drivers.csv")

# %%
driver_standings=pd.read_csv("driver_standings.csv")

# %%
driver_standings.isna()
# Out:
#        driverStandingsId  raceId  driverId  points  position  positionText  \
# 0                  False   False     False   False     False         False
# 1                  False   False     False   False     False         False
# 2                  False   False     False   False     False         False
# 3                  False   False     False   False     False         False
# 4                  False   False     False   False     False         False
# ...                  ...     ...       ...     ...       ...           ...
# 33389              False   False     False   False     False         False
# 33390              False   False     False   False     False         False
# 33391              False   False     False   False     False         False
# 33392              False   False     False   False     False         False
# 33393              False   False     False   False     False         False
#
#         wins
# 0      False
# 1      False
# 2      False
# ...

# %%
constructors.isna().sum()
# Out:
# constructorId     0
# constructorRef    0
# name              0
# nationality       0
# url               0
# dtype: int64

# %%
drivers.isna().sum()
# Out:
# driverId       0
# driverRef      0
# number         0
# code           0
# forename       0
# surname        0
# dob            0
# nationality    0
# url            0
# dtype: int64

# %%
Const_standings.isna().sum()
# Out:
# constructorStandingsId    0
# raceId                    0
# constructorId             0
# points                    0
# position                  0
# positionText              0
# wins                      0
# dtype: int64

# %%
# there is no missing data in any of the above

# %%
#slicing using loc and iloc

# %%
Const_standings
# Out:
#        constructorStandingsId  raceId  constructorId  points  position  \
# 0                           1      18              1    14.0         1
# 1                           2      18              2     8.0         3
# 2                           3      18              3     9.0         2
# 3                           4      18              4     5.0         4
# 4                           5      18              5     2.0         5
# ...                       ...     ...            ...     ...       ...
# 12711                   27938    1074            210     0.0         6
# 12712                   27939    1074              1     0.0         7
# 12713                   27940    1074            131     0.0         8
# 12714                   27941    1074              9     0.0         9
# 12715                   27942    1074              3     0.0        10
#
#       positionText  wins
# 0                1     1
# 1                3     0
# 2                2     0
# ...

# %%
Const_standings.loc["constructorId":"position"]
# Out:
# Empty DataFrame
# Columns: [constructorStandingsId, raceId, constructorId, points, position, positionText, wins]
# Index: []

# %%
drivers
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  07/01/1985
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  10/05/1977
# 2           3          rosberg      6  ROS      Nico     Rosberg  27/06/1985
# 3           4           alonso     14  ALO  Fernando      Alonso  29/07/1981
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  19/10/1981
# ..        ...              ...    ...  ...       ...         ...         ...
# 849       851           aitken     89  AIT      Jack      Aitken  23/09/1995
# 850       852          tsunoda     22  TSU      Yuki     Tsunoda  11/05/2000
# 851       853          mazepin      9  MAZ    Nikita     Mazepin  02/03/1999
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  22/03/1999
# 853       855             zhou     \N  ZHO    Guanyu        Zhou  30/05/1999
#
# ...

# %%
drivers.loc[:,("driverRef","nationality")]
# Out:
#            driverRef nationality
# 0           hamilton     British
# 1           heidfeld      German
# 2            rosberg      German
# 3             alonso     Spanish
# 4         kovalainen     Finnish
# ..               ...         ...
# 849           aitken     British
# 850          tsunoda    Japanese
# 851          mazepin     Russian
# 852  mick_schumacher      German
# 853             zhou     Chinese
#
# [854 rows x 2 columns]

# %%
drivers.loc[:,("forename","surname","nationality")]
# Out:
#      forename     surname nationality
# 0       Lewis    Hamilton     British
# 1        Nick    Heidfeld      German
# 2        Nico     Rosberg      German
# 3    Fernando      Alonso     Spanish
# 4      Heikki  Kovalainen     Finnish
# ..        ...         ...         ...
# 849      Jack      Aitken     British
# 850      Yuki     Tsunoda    Japanese
# 851    Nikita     Mazepin     Russian
# 852      Mick  Schumacher      German
# 853    Guanyu        Zhou     Chinese
#
# [854 rows x 3 columns]

# %%
#slicing re dob years using iloc

# %%
drivers.iloc[:,[(4),(5),(6)]]
# Out:
#      forename     surname         dob
# 0       Lewis    Hamilton  07/01/1985
# 1        Nick    Heidfeld  10/05/1977
# 2        Nico     Rosberg  27/06/1985
# 3    Fernando      Alonso  29/07/1981
# 4      Heikki  Kovalainen  19/10/1981
# ..        ...         ...         ...
# 849      Jack      Aitken  23/09/1995
# 850      Yuki     Tsunoda  11/05/2000
# 851    Nikita     Mazepin  02/03/1999
# 852      Mick  Schumacher  22/03/1999
# 853    Guanyu        Zhou  30/05/1999
#
# [854 rows x 3 columns]

# %%
drivers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 854 entries, 0 to 853
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   driverId     854 non-null    int64
#  1   driverRef    854 non-null    object
#  2   number       854 non-null    object
#  3   code         854 non-null    object
#  4   forename     854 non-null    object
#  5   surname      854 non-null    object
#  6   dob          854 non-null    object
#  7   nationality  854 non-null    object
#  8   url          854 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 60.2+ KB

# %%
#looping

# %%
drivers.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  07/01/1985
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  10/05/1977
# 2         3     rosberg      6  ROS      Nico     Rosberg  27/06/1985
# 3         4      alonso     14  ALO  Fernando      Alonso  29/07/1981
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  19/10/1981
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
top_five_drivers = {"surname" : ["Hamilton", "Heidfield","Rosberg","Alonso","Kovalainen"],
                    "dob" : ["07/01/1985","10/05/1977","27/06/1985","29/07/1981","19/10/1981"],
                    "nationality" : ["British","German","German","Spanish","Finnish"]}

# %%
for rows in top_five_drivers :
    print(rows)
# Out:
# surname
# dob
# nationality

# %%
for row in top_five_drivers.items():
    print(row)
# Out:
# ('surname', ['Hamilton', 'Heidfield', 'Rosberg', 'Alonso', 'Kovalainen'])
# ('dob', ['07/01/1985', '10/05/1977', '27/06/1985', '29/07/1981', '19/10/1981'])
# ('nationality', ['British', 'German', 'German', 'Spanish', 'Finnish'])

# %%
for key, value in top_five_drivers.items() :
    print(key + " of top five drivers " + str(value))
# Out:
# surname of top five drivers ['Hamilton', 'Heidfield', 'Rosberg', 'Alonso', 'Kovalainen']
# dob of top five drivers ['07/01/1985', '10/05/1977', '27/06/1985', '29/07/1981', '19/10/1981']
# nationality of top five drivers ['British', 'German', 'German', 'Spanish', 'Finnish']

# %%
import numpy as np

# %%
np_surname = ['Hamilton', 'Heidfield', 'Rosberg', 'Alonso', 'Kovalainen']

# %%
np_nationality = ["British","German","German","Spanish","Finnish"]

# %%
top_five_drivers_surname_nationality = np.array([np_surname])

# %%
    for val in np.nditer(top_five_drivers_surname_nationality) :
        print (val)
# Out:
# Hamilton
# Heidfield
# Rosberg
# Alonso
# Kovalainen

# %%
#iterrows

# %%
drivers=pd.read_csv("F1 Drivers.csv",index_col=1)

# %%
print(drivers)
# Out:
#                  driverId number code  forename     surname         dob  \
# driverRef
# hamilton                1     44  HAM     Lewis    Hamilton  07/01/1985
# heidfeld                2     \N  HEI      Nick    Heidfeld  10/05/1977
# rosberg                 3      6  ROS      Nico     Rosberg  27/06/1985
# alonso                  4     14  ALO  Fernando      Alonso  29/07/1981
# kovalainen              5     \N  KOV    Heikki  Kovalainen  19/10/1981
# ...                   ...    ...  ...       ...         ...         ...
# aitken                851     89  AIT      Jack      Aitken  23/09/1995
# tsunoda               852     22  TSU      Yuki     Tsunoda  11/05/2000
# mazepin               853      9  MAZ    Nikita     Mazepin  02/03/1999
# mick_schumacher       854     47  MSC      Mick  Schumacher  22/03/1999
# zhou                  855     \N  ZHO    Guanyu        Zhou  30/05/1999
#
#                 nationality                                             url
# driverRef
# ...

# %%
for val in drivers :
    print (val)
# Out:
# driverId
# number
# code
# forename
# surname
# dob
# nationality
# url

# %%
for lab, row in drivers.iterrows():
    print(type(lab))
    print(type(row))
# Out:
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# <class 'pandas.core.series.Series'>
# <class 'str'>
# ...

# %%
for lab, row in drivers.iterrows():
    print("Label: " + lab)
    print(row)
# Out:
# Label: hamilton
# driverId                                                 1
# number                                                  44
# code                                                   HAM
# forename                                             Lewis
# surname                                           Hamilton
# dob                                             07/01/1985
# nationality                                        British
# url            http://en.wikipedia.org/wiki/Lewis_Hamilton
# Name: hamilton, dtype: object
# Label: heidfeld
# driverId                                                2
# number                                                 \N
# code                                                  HEI
# forename                                             Nick
# surname                                          Heidfeld
# dob                                            10/05/1977
# nationality                                        German
# ...
